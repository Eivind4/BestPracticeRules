# %% [markdown]
# # 🎿 FABRIC FEBRUARY 05.02.2026
# ## Best Practices for Best Practice Rules
# ### Automate Development of Semantic Models with Quality
#
# *Welcome to the starting gate!* ⛷️

# %% [markdown]
# ### 📚 REFERENCES
#
# All code and functions are provided by Microsoft:
#
# #### Helper Notebooks
# - 🔗 [Semantic Link Labs GitHub Repository](https://github.com/microsoft/semantic-link-labs)
# - 📊 [Best Practice Analyzer Report](https://github.com/microsoft/semantic-link-labs/blob/main/notebooks/Best%20Practice%20Analyzer%20Report.ipynb)
# - ⚡ [Model Optimization](https://github.com/microsoft/semantic-link-labs/blob/main/notebooks/Model%20Optimization.ipynb)
#
# #### Code Examples
# - 💡 [Model Best Practice Analyzer Examples](https://github.com/microsoft/semantic-link-labs/wiki/Code-Examples#model-best-practice-analyzer)

# %% [markdown]
# ### 📦 Install the Latest Package
#
# *First checkpoint: Let's gear up with the right equipment!*
#
# Check [PyPI](https://pypi.org/project/semantic-link-labs/) to see the latest version of semantic-link-labs.

# %%
# %pip install semantic-link-labs
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 17, Finished, Available, Finished)
# Requirement already satisfied: semantic-link-labs in /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages (0.12.10)
# Requirement already satisfied: semantic-link-sempy>=0.13.0 in /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages (from semantic-link-labs) (0.13.0)
# Requirement already satisfied: anytree in /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages (from semantic-link-labs) (2.13.0)
# Requirement already satisfied: polib in /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages (from semantic-link-labs) (1.2.0)
# Requirement already satisfied: jsonpath_ng in /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages (from semantic-link-labs) (1.7.0)
# Requirement already satisfied: clr_loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (0.2.5)
# Requirement already satisfied: fabric-analytics-sdk<1.0.0,>=0.0.2 in /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages (from fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.0.3.post1)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (0.20.1)
# Requirement already satisfied: azure-storage-blob>=12.18.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (12.22.0)
# Requirement already satisfied: azure-core>=1.29.4 in /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (1.38.0)
# Requirement already satisfied: azure-keyvault-secrets>=4.7.0 in /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (4.10.0)
# Requirement already satisfied: azure-storage-file-datalake>=12.12.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (12.16.0)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit_learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (13.3.5)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (2023.10.3)
# Requirement already satisfied: pandas>=1.5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (2.1.4)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (2.4.0)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (3.9.3)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.13.0->semantic-link-labs) (8.2.3)
# Requirement already satisfied: ply in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonpath_ng->semantic-link-labs) (3.11)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.13.0->semantic-link-labs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.13.0->semantic-link-labs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.9.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-core>=1.29.4->semantic-link-sempy>=0.13.0->semantic-link-labs) (4.9.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.6.1)
# Requirement already satisfied: cryptography>=2.1.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-storage-blob>=12.18.3->semantic-link-sempy>=0.13.0->semantic-link-labs) (42.0.2)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr_loader>=0.2.5->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.16.0)
# Requirement already satisfied: azure-identity in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-sdk<1.0.0,>=0.0.2->fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.15.0)
# Requirement already satisfied: fabric-analytics-notebook-plugin in /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages (from fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.0.3)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (4.8.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.13.0->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.13.0->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.5.3->semantic-link-sempy>=0.13.0->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.13.0->semantic-link-labs) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn>=1.2.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn>=1.2.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn>=1.2.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (2.2.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr_loader>=0.2.5->semantic-link-sempy>=0.13.0->semantic-link-labs) (2.21)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from isodate>=0.6.1->azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.2.5)
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-sdk<1.0.0,>=0.0.2->fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.25.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-sdk<1.0.0,>=0.0.2->fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.0.0)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin->fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (5.9.0)
# Requirement already satisfied: synapseml-utils in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin->fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.1.6.post2)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.2.2)
# Requirement already satisfied: portalocker<3,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity->fabric-analytics-sdk<1.0.0,>=0.0.2->fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (2.3.0)
# Requirement already satisfied: fluent-logger in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from synapseml-utils->fabric-analytics-notebook-plugin->fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.10.0)
# Requirement already satisfied: gson in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from synapseml-utils->fabric-analytics-notebook-plugin->fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (0.0.4)
# Requirement already satisfied: msgpack>1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fluent-logger->synapseml-utils->fabric-analytics-notebook-plugin->fabric-analytics-sdk[online-notebook]<1.0.0,>=0.0.2->semantic-link-sempy>=0.13.0->semantic-link-labs) (1.0.3)
#
# [notice] A new release of pip is available: 24.0 -> 26.0
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %% [markdown]
# ### 🚀 Import the Library
#
# *Find the skiing equipment you need*

# %%
import sempy_labs as labs
from sempy_labs import lakehouse as lake
from sempy_labs import directlake
import sempy_labs.report as rep

dataset = 'Fabric February - Best Practice Rules - StartGate'   
dataset_modified = 'Fabric February - Best Practice Rules - Demo'
workspace = 'Best Practice Analyzer'
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 19, Finished, Available, Finished)

# %% [markdown]
# ### 🎯 BPA for a Single Semantic Model
#
# *First run down the slope - let's check our model!*
#
# #### Will it return the same result as in Tabular Editor (TE)?

# %%
labs.run_model_bpa(dataset=dataset, workspace=workspace)
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 20, Finished, Available, Finished)
#     <style>
#         .tab { overflow: hidden; border: 1px solid #ccc; background-color: #f1f1f1; }
#         .tab button { background-color: inherit; float: left; border: none; outline: none; cursor: pointer; padding: 14px 16px; transition: 0.3s; }
#         .tab button:hover { background-color: #ddd; }
#         .tab button.active { background-color: #ccc; }
#         .tabcontent { display: none; padding: 6px 12px; border: 1px solid #ccc; border-top: none; }
#         .tabcontent.active { display: block; }
#         .tooltip { position: relative; display: inline-block; }
#         .tooltip .tooltiptext { visibility: hidden; width: 300px; background-color: #555; color: #fff; text-align: center; border-radius: 6px; padding: 5px; position: absolute; z-index: 1; bottom: 125%; left: 50%; margin-left: -110px; opacity: 0; transition: opacity 0.3s; }
#         .tooltip:hover .tooltiptext { visibility: visible; opacity: 1; }
#     </style>
#     <div class="tab"><button class="tablinks active" onclick="openTab(event, 'tab0')"><b>DAX Expressions</b><br/>⚠️ (1)</button><button class="tablinks " onclick="openTab(event, 'tab1')"><b>Formatting</b><br/>ℹ️ (21) + ⚠️ (17)</button><button class="tablinks " onclick="openTab(event, 'tab2')"><b>Maintenance</b><br/>ℹ️ (73) + ⚠️ (1)</button><button class="tablinks " onclick="openTab(event, 'tab3')"><b>Performance</b><br/>⚠️ (4)</button></div><div id="tab0" class="tabcontent active"><table border="1"><tr><th>Rule Name</th><th>Object Type</th><th>Object Name</th><th>Severity</th></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://dax.guide/userelationship">Inactive relationships that are never activated</a><span class="tooltiptext">Inactive relationships are activated using the USERELATIONSHIP function. If an inactive relationship is not referenced in any measure via this function, the relationship will not be used. It should be determined whether the relationship is not necessary or to activate the relationship via this method.</span></td><td>Relationship</td><td>'Sales'[Delivery Date] -> 'Calendar'[Date]</td><td style="text-align: center;">⚠️</td></tr></table></div><div id="tab1" class="tabcontent "><table border="1"><tr><th>Rule Name</th><th>Object Type</th><th>Object Name</th><th>Severity</th></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/transform-model/desktop-data-categorization">Add data category for columns</a><span class="tooltiptext">Add Data Category property for appropriate columns.</span></td><td>Column</td><td>'Customer'[City]</td><td style="text-align: center;">ℹ️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/transform-model/desktop-data-categorization">Add data category for columns</a><span class="tooltiptext">Add Data Category property for appropriate columns.</span></td><td>Column</td><td>'Customer'[Continent]</td><td style="text-align: center;">ℹ️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/transform-model/desktop-data-categorization">Add data category for columns</a><span class="tooltiptext">Add Data Category property for appropriate columns.</span></td><td>Column</td><td>'Customer'[Country Code]</td><td style="text-align: center;">ℹ️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/transform-model/desktop-data-categorization">Add data category for columns</a><span class="tooltiptext">Add Data Category property for appropriate columns.</span></td><td>Column</td><td>'Customer'[Country]</td><td style="text-align: center;">ℹ️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://docs.microsoft.com/power-bi/transform-model/desktop-data-categorization">Add data category for columns</a><span class="tooltiptext">Add Data Category property for appropriate columns.</span></td><td>Column</td><td>'Store'[Country]</td><td style="text-align: center;">ℹ️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'Sales'[Exchange Rate]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'Sales'[Line Number]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseo ...

# %% [markdown]
# ### 📊 Results Comparison
#
# **Tabular Editor (TE):** 125 violations
# **Semantic Link Labs (SLL):** 117 violations
#
# ### 🔍 Reasons for Deviation Between TE and SLL
#
# **The Microsoft rules are not 1:1**
# - ✨ More recent rules in SLL (e.g., Direct Lake support)
# - 📈 Vertipaq Analyzer results not used in SLL
#
# **Ignored Rules**
# - 🏷️ Possible reason: Do not catch annotations (by default)
#
# *Like comparing slalom and giant slalom - same sport, different gates!*

# %% [markdown]
# ### 🛠️ Is it Possible to FIX the Violations?
#
# **Yes!** But be warned - there's no Ctrl+Z option (no safety net!) ⚠️
#
# #### Example: Setting IsAvailableInMDX
# *From the code examples - you get to go skiing with the ski-instructor!*
# *But mostly you will have to go skiing by yourself to make Notebooks actionable!*

# %%
from sempy_labs.tom import connect_semantic_model

with connect_semantic_model(dataset=dataset, workspace=workspace, readonly=False) as tom:
    
    # Example 1: For a specific column
 #   tom.model.Tables['TableName'].Columns['ColumnName'].IsAvailableInMDX = False

    # Example 2: For all relevant columns (according to the [Model BPA rule](https://github.com/microsoft/semantic-link-labs/blob/b1626d1dc0d041f3b19d1a1c9b38c0039f718382/src/sempy_labs/_model_bpa_rules.py#L110))
    if not tom.is_direct_lake():
        for c in tom.all_columns():
            if c.IsAvailableInMDX and (c.IsHidden or c.Parent.IsHidden) and c.SortByColumn is None and not any(tom.used_in_sort_by(column=c)) and not any(tom.used_in_hierarchies(column=c)):
                c.IsAvailableInMDX = False
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 21, Finished, Available, Finished)

# %% [markdown]
# ### 💾 Save Your Results to a Lakehouse Table
#
# This runs the Best Practice Analyzer and exports the results to the **'modelbparesults'** delta table in your Fabric lakehouse.
#
# **📋 Requirements:**
# - Connected lakehouse is required
#
# *Store your race results for future analysis - improve your skiing!* 🏔️

# %%
labs.run_model_bpa(dataset=dataset, workspace=workspace, export=True)
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 22, Finished, Available, Finished)
# 🟢 The dataframe has been saved as the 'modelbparesults' table in the 'lh_BestPracticeAnalyzer' lakehouse within the 'Best Practice Analyzer' workspace.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>💡 Pro Tip:</b> For analyzing model BPA results at scale across multiple models, check out the <b>Best Practice Analyzer Report</b> notebook below.
# </div>
#
# 📖 [Best Practice Analyzer Report](https://github.com/microsoft/semantic-link-labs/blob/main/notebooks/Best%20Practice%20Analyzer%20Report.ipynb)
#
# *Think of it as your season statistics dashboard!*

# %% [markdown]
# ### 🌐 Multiple Models / Workspaces
#
# *Expanding our course - analyzing the entire ski resort!* ⛷️

# %%
#Collect stats for all semantic models within a single workspace
labs.run_model_bpa_bulk(workspace=workspace)

#Collect stats for all semantic models within a list of workspaces
#labs.run_model_bpa_bulk(workspace=['Workspace 1', 'Workspace 2'])

#Collect stats for all semantic models within all accessible workspaces
#labs.run_model_bpa_bulk(workspace=None)
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 23, Finished, Available, Finished)
# ⌛ Collecting Model BPA stats for the 'Fabric February - Best Practice Rules - StartGate' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 Collected Model BPA stats for the 'Fabric February - Best Practice Rules - StartGate' semantic model within the 'Best Practice Analyzer' workspace.
# ⌛ Collecting Model BPA stats for the 'Fabric February - Best Practice Rules - Demo' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 Collected Model BPA stats for the 'Fabric February - Best Practice Rules - Demo' semantic model within the 'Best Practice Analyzer' workspace.
# ⌛ Saving the Model BPA results of the 'Best Practice Analyzer' workspace to the 'modelbparesults' within the lakehouse attached to this notebook...
# 🟢 The dataframe has been saved as the 'modelbparesults' table in the 'lh_BestPracticeAnalyzer' lakehouse within the 'Best Practice Analyzer' workspace.
# 🟢 Saved BPA results to the 'modelbparesults' delta table.
# 🟢 Bulk BPA scan complete.

# %% [markdown]
# ### 🎿 Create Direct Lake BPA Model
#
# *Building our performance dashboard - fresh tracks on the data lake!*

# %%
labs.create_model_bpa_semantic_model()
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 24, Finished, Available, Finished)
# 🟢 The 'ModelBPA' semantic model was created within the 'Best Practice Analyzer' workspace.
# 🟢 The 'BPAResults' table has been added to the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'modelbparesults' partition has been added to the 'BPAResults' table in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Capacity_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Capacity_Id' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Workspace_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Workspace_Id' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Dataset_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Dataset_Id' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Configured_By' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Rule_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Category' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Severity' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Object_Type' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Object_Name' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Description' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'URL' column has been added to the 'BPAResults' table as a 'String' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'RunId' column has been added to the 'BPAResults' table as a 'Int64' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# 🟢 The 'Timestamp' column has been added to the 'BPAResults' table as a 'DateTime' data type in the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace.
# ⌛ Refresh of the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace is in progress...
# 🟢 Refresh 'full' of the 'ModelBPA' semantic model within the 'Best Practice Analyzer' workspace is complete.

# %% [markdown]
# ### 📊 Create Report to Analyze BPA Results
#
# *Your personalized scoreboard - visualize the performance metrics!*

# %%
rep.create_model_bpa_report()
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 25, Finished, Available, Finished)
# /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages/sempy/fabric/_credentials.py:239: FutureWarning: The 'type' parameter is deprecated and will be removed in a future version. Use 'item_type' instead.
#   return func(*args, **kwargs)
# /nfs4/pyenv-4fa3998f-fc4a-4dc1-bcfb-4743ab5f7521/lib/python3.11/site-packages/sempy/fabric/_credentials.py:239: FutureWarning: The 'type' parameter is deprecated and will be removed in a future version. Use 'item_type' instead.
#   return func(*args, **kwargs)
# 🟢 Succesfully created the 'ModelBPA' report within the 'Best Practice Analyzer' workspace.

# %% [markdown]
# #### 🎯 Tailor rules in SLL
#
# The "secret recipe" can be found here:
# 🔗 [Model BPA Rules Source Code](https://github.com/microsoft/semantic-link-labs/blob/main/src/sempy_labs/_model_bpa_rules.py)
#
# **Run BPA using your own custom best practice rules**
#
# *Let's take the ski lift back up once more!*

# %%
import sempy
sempy.fabric._client._utils._init_analysis_services()
import Microsoft.AnalysisServices.Tabular as TOM
import pandas as pd
import re


rules = pd.DataFrame(
    [
            (
                "Performance",
                "Column",
                "Warning",
                "Set IsAvailableInMdx to false on non-attribute columns",
                lambda obj, tom: tom.is_direct_lake() is False
                and obj.IsAvailableInMDX
                and (obj.IsHidden or obj.Parent.IsHidden)
                and obj.SortByColumn is None
                and not any(tom.used_in_sort_by(column=obj))
                and not any(tom.used_in_hierarchies(column=obj)),
                "To speed up processing time and conserve memory after processing, attribute hierarchies should not be built for columns that are never used for slicing by MDX clients. In other words, all hidden columns that are not used as a Sort By Column or referenced in user hierarchies should have their IsAvailableInMdx property set to false. The IsAvailableInMdx property is not relevant for Direct Lake models.",
                "https://blog.crossjoin.co.uk/2018/07/02/isavailableinmdx-ssas-tabular",
            ),
            (
                "Performance",
                "Table",
                "Warning",
                "Date/calendar tables should be marked as a date table",
                lambda obj, tom: (
                    re.search(r"date", obj.Name, flags=re.IGNORECASE)
                    or re.search(r"calendar", obj.Name, flags=re.IGNORECASE)
                )
                and str(obj.DataCategory) != "Time",
                "This rule looks for tables that contain the words 'date' or 'calendar' as they should likely be marked as a date table.",
                "https://docs.microsoft.com/power-bi/transform-model/desktop-date-tables",
            ),
            (
                "Performance",
                "Model",
                "Warning",
                "Model should have a date table",
                lambda obj, tom: not any(
                    (c.IsKey and c.DataType == TOM.DataType.DateTime)
                    and str(t.DataCategory) == "Time"
                    for t in obj.Tables
                    for c in t.Columns
                ),
                "Generally speaking, models should generally have a date table. Models that do not have a date table generally are not taking advantage of features such as time intelligence or may not have a properly structured architecture.",
            ),
            (
                "DAX Expressions",
                "Measure",
                "Warning",
                "No two measures should have the same definition",
                lambda obj, tom: any(
                    re.sub(r"\s+", "", obj.Expression)
                    == re.sub(r"\s+", "", m.Expression)
                    and obj.Name != m.Name
                    for m in tom.all_measures()
                ),
                "Two measures with different names and defined by the same DAX expression should be avoided to reduce redundancy.",
            ),
             (
                "DAX Expressions",
                "Relationship",
                "Warning",
                "Inactive relationships that are never activated",
                lambda obj, tom: obj.IsActive is False
                and not any(
                    re.search(
                        r"USERELATIONSHIP\s*\(\s*\'*"
                        + re.escape(obj.FromTable.Name)
                        + r"'*\["
                        + re.escape(obj.FromColumn.Name)
                        + r"\]\s*,\s*'*"
                        + re.escape(obj.ToTable.Name)
                        + r"'*\["
                        + re.escape(obj.ToColumn.Name)
                        + r"\]",
                        m.Expression,
                        flags=re.IGNORECASE,
                    )
                    for m in tom.all_measures()
                ),
                "Inactive relationships are activated using the USERELATIONSHIP function. If an inactive relationship is not referenced in any measure via this function, the relationship will not be used. It should be determined whether the relationship is not necessary or to activate the relationship via this method.",
                "https://dax.guide/userelationship",
            ),
            (
                "Maintenance",
                "Table",
                "Warning",
                "Ensure tables have relationships",
                lambda obj, tom: any(tom.used_in_relationships(object=obj)) is False
                and obj.CalculationGroup is None,
                "This rule highlights tables which are not connected to any other table in the model with a relationship.",
            ),
            (
                "Maintenance",
                ["Column", "Measure", "Table"],
                "Info",
                "Visible objects with no description",
                lambda obj, tom: obj.IsHidden is False and len(obj.Description) == 0,
                "Add descriptions to objects. These descriptions are shown on hover within the Field List in Power BI Desktop. Additionally, you can leverage these descriptions to create an automated data dictionary.",
            ),
             (
                "Formatting",
                "Column",
                "Warning",
                "Provide format string for 'Date' columns",
                lambda obj, tom: (re.search(r"date", obj.Name, flags=re.IGNORECASE))
                and (obj.DataType == TOM.DataType.DateTime)
                and (
                    obj.FormatString.lower()
                    not in [
                        "mm/dd/yyyy",
                        "mm-dd-yyyy",
                        "dd/mm/yyyy",
                        "dd-mm-yyyy",
                        "yyyy-mm-dd",
                        "yyyy/mm/dd",
                    ]
                ),
                'Columns of type "DateTime" that have "Date" in their names should be formatted.',
            ),
            (
                "Formatting",
                "Column",
                "Warning",
                "Do not summarize numeric columns",
                lambda obj, tom: (
                    (obj.DataType == TOM.DataType.Int64)
                    or (obj.DataType == TOM.DataType.Decimal)
                    or (obj.DataType == TOM.DataType.Double)
                )
                and (str(obj.SummarizeBy) != "None")
                and not ((obj.IsHidden) or (obj.Parent.IsHidden)),
                'Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).',
            ),
             (
                "Formatting",
                "Measure",
                "Info",
                "Provide format string for measures",
                lambda obj, tom: obj.IsHidden is False and len(obj.FormatString) == 0,
                "Visible measures should have their format string property assigned.",
            ),
             (
                "Formatting",
                "Measure",
                "Warning",
                "Percentages should be formatted with thousands separators and 1 decimal",
                lambda obj, tom: "%" in obj.FormatString
                and obj.FormatString != "#,0.0%;-#,0.0%;#,0.0%",
                "For a better user experience, percengage measures should be formatted with a '%' sign.",
            ),
             (
                "Formatting",
                "Column",
                "Info",
                "Hide foreign keys",
                lambda obj, tom: obj.IsHidden is False
                and any(
                    r.FromColumn.Name == obj.Name
                    and r.FromCardinality == TOM.RelationshipEndCardinality.Many
                    for r in tom.used_in_relationships(object=obj)
                ),
                "Foreign keys should always be hidden as they should not be used by end users.",
            ),
            (
                "Formatting",
                "Column",
                "Info",
                "Month (as a string) must be sorted",
                lambda obj, tom: (re.search(r"month", obj.Name, flags=re.IGNORECASE))
                and not (re.search(r"months", obj.Name, flags=re.IGNORECASE))
                and (obj.DataType == TOM.DataType.String)
                and len(str(obj.SortByColumn)) == 0,
                "This rule highlights month columns which are strings and are not sorted. If left unsorted, they will sort alphabetically (i.e. April, August...). Make sure to sort such columns so that they sort properly (January, February, March...).",
            ),
            (
                "Formatting",
                "Column",
                "Warning",
                "Provide format string for 'Month' columns",
                lambda obj, tom: re.search(r"month", obj.Name, flags=re.IGNORECASE)
                and obj.DataType == TOM.DataType.DateTime
                and obj.FormatString != "MMMM yyyy",
                'Columns of type "DateTime" that have "Month" in their names should be formatted as "MMMM yyyy".',
            )
    ],
    columns=[
            "Category",
            "Scope",
            "Severity",
            "Rule Name",
            "Expression",
            "Description",
            "URL",
        ],
)

labs.run_model_bpa(dataset=dataset, workspace=workspace, rules=rules)
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 26, Finished, Available, Finished)
#     <style>
#         .tab { overflow: hidden; border: 1px solid #ccc; background-color: #f1f1f1; }
#         .tab button { background-color: inherit; float: left; border: none; outline: none; cursor: pointer; padding: 14px 16px; transition: 0.3s; }
#         .tab button:hover { background-color: #ddd; }
#         .tab button.active { background-color: #ccc; }
#         .tabcontent { display: none; padding: 6px 12px; border: 1px solid #ccc; border-top: none; }
#         .tabcontent.active { display: block; }
#         .tooltip { position: relative; display: inline-block; }
#         .tooltip .tooltiptext { visibility: hidden; width: 300px; background-color: #555; color: #fff; text-align: center; border-radius: 6px; padding: 5px; position: absolute; z-index: 1; bottom: 125%; left: 50%; margin-left: -110px; opacity: 0; transition: opacity 0.3s; }
#         .tooltip:hover .tooltiptext { visibility: visible; opacity: 1; }
#     </style>
#     <div class="tab"><button class="tablinks active" onclick="openTab(event, 'tab0')"><b>DAX Expressions</b><br/>⚠️ (1)</button><button class="tablinks " onclick="openTab(event, 'tab1')"><b>Formatting</b><br/>⚠️ (12) + ℹ️ (11)</button><button class="tablinks " onclick="openTab(event, 'tab2')"><b>Maintenance</b><br/>ℹ️ (73) + ⚠️ (1)</button><button class="tablinks " onclick="openTab(event, 'tab3')"><b>Performance</b><br/>⚠️ (2)</button></div><div id="tab0" class="tabcontent active"><table border="1"><tr><th>Rule Name</th><th>Object Type</th><th>Object Name</th><th>Severity</th></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)"><a href="https://dax.guide/userelationship">Inactive relationships that are never activated</a><span class="tooltiptext">Inactive relationships are activated using the USERELATIONSHIP function. If an inactive relationship is not referenced in any measure via this function, the relationship will not be used. It should be determined whether the relationship is not necessary or to activate the relationship via this method.</span></td><td>Relationship</td><td>'Sales'[Delivery Date] -> 'Calendar'[Date]</td><td style="text-align: center;">⚠️</td></tr></table></div><div id="tab1" class="tabcontent "><table border="1"><tr><th>Rule Name</th><th>Object Type</th><th>Object Name</th><th>Severity</th></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'Sales'[Exchange Rate]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'Sales'[Line Number]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'Sales'[Net Price]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'Sales'[Order Number]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'Sales'[Quantity]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'Sales'[Unit Cost]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</ ...

# %% [markdown]
# #### 🌍 Apply tailored rules for All Models in a Workspace

# %%
labs.run_model_bpa_bulk(workspace=workspace, rules=rules)
# Out:
# StatementMeta(, b0723417-70aa-44a0-8c2c-9dc24e5e7c95, 27, Submitted, Running, Running)
